# %% [markdown]
# # Brand Sentiment Analysis Dashboard
# This notebook walks through the full workflow: dataset creation, preprocessing, model training, evaluation, and visualization.

# %%
from src.data_generator import save_dataset
from src.train_model import train_and_save_model
from src.visualize import create_visualizations
from src.insights import build_insights

df = save_dataset()
df.head()

# %%
df, metrics, top_keywords = train_and_save_model(force_regenerate_data=False)
metrics

# %%
create_visualizations(df, top_keywords)
insights = build_insights(df, metrics, top_keywords)
insights

# %% [markdown]
# ## Learning note
# The interesting part of this project was not only the prediction step. The real value came from turning text into something that can be read in a business context.
